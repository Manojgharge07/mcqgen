# %%
pip install pandas
# Out:
# Collecting pandas
#   Using cached pandas-2.2.3-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Collecting numpy>=1.26.0 (from pandas)
#   Downloading numpy-2.2.1-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\manoj\mcqgen\env\lib\site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Using cached pytz-2024.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Using cached tzdata-2024.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in c:\users\manoj\mcqgen\env\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Using cached pandas-2.2.3-cp312-cp312-win_amd64.whl (11.5 MB)
# Downloading numpy-2.2.1-cp312-cp312-win_amd64.whl (12.6 MB)
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.6 MB ? eta -:--:--
#    - -------------------------------------- 0.5/12.6 MB 1.0 MB/s eta 0:00:12
#    -- ------------------------------------- 0.8/12.6 MB 958.5 kB/s eta 0:00:13
#    --- ------------------------------------ 1.0/12.6 MB 1.0 MB/s eta 0:00:12
#    --- ------------------------------------ 1.0/12.6 MB 1.0 MB/s eta 0:00:12
#    ---- ----------------------------------- 1.3/12.6 MB 1.0 MB/s eta 0:00:12
#    ---- ----------------------------------- 1.6/12.6 MB 1.0 MB/s eta 0:00:11
#    ----- ---------------------------------- 1.8/12.6 MB 1.0 MB/s eta 0:00:11
#    ----- ---------------------------------- 1.8/12.6 MB 1.0 MB/s eta 0:00:11
#    ------ --------------------------------- 2.1/12.6 MB 962.8 kB/s eta 0:00:11
#    ------- -------------------------------- 2.4/12.6 MB 932.1 kB/s eta 0:00:12
#    ------- -------------------------------- 2.4/12.6 MB 932.1 kB/s eta 0:00:12
#    -------- ------------------------------- 2.6/12.6 MB 932.2 kB/s eta 0:00:11
#    --------- ------------------------------ 3.1/12.6 MB 1.0 MB/s eta 0:00:10
#    ---------- ----------------------------- 3.4/12.6 MB 1.0 MB/s eta 0:00:09
#    ----------- ---------------------------- 3.7/12.6 MB 1.0 MB/s eta 0:00:09
#    ------------ --------------------------- 3.9/12.6 MB 1.0 MB/s eta 0:00:09
#    ------------- -------------------------- 4.2/12.6 MB 1.1 MB/s eta 0:00:08
#    -------------- ------------------------- 4.5/12.6 MB 1.1 MB/s eta 0:00:08
#    -------------- ------------------------- 4.5/12.6 MB 1.1 MB/s eta 0:00:08
#    -------------- ------------------------- 4.7/12.6 MB 1.1 MB/s eta 0:00:08
#    --------------- ------------------------ 5.0/12.6 MB 1.0 MB/s eta 0:00:08
#    --------------- ------------------------ 5.0/12.6 MB 1.0 MB/s eta 0:00:08
#    ----------------- ---------------------- 5.5/12.6 MB 1.1 MB/s eta 0:00:07
#    ------------------ --------------------- 5.8/12.6 MB 1.1 MB/s eta 0:00:07
#    ------------------- -------------------- 6.0/12.6 MB 1.1 MB/s eta 0:00:07
#    ------------------- -------------------- 6.3/12.6 MB 1.1 MB/s eta 0:00:06
#    ------------------- -------------------- 6.3/12.6 MB 1.1 MB/s eta 0:00:06
#    ------------------- -------------------- 6.3/12.6 MB 1.1 MB/s eta 0:00:06
#    ------------------- -------------------- 6.3/12.6 MB 1.1 MB/s eta 0:00:06
#    ------------------- -------------------- 6.3/12.6 MB 1.1 MB/s eta 0:00:06
#    --------------------- ------------------ 6.8/12.6 MB 984.6 kB/s eta 0:00:06
#    ---------------------- ----------------- 7.1/12.6 MB 986.9 kB/s eta 0:00:06
#    ---------------------- ----------------- 7.1/12.6 MB 986.9 kB/s eta 0:00:06
#    ----------------------- ---------------- 7.3/12.6 MB 972.1 kB/s eta 0:00:06
#    ----------------------- ---------------- 7.3/12.6 MB 972.1 kB/s eta 0:00:06
#    ------------------------ --------------- 7.6/12.6 MB 958.7 kB/s eta 0:00:06
#    ------------------------ --------------- 7.9/12.6 MB 963.4 kB/s eta 0:00:05
#    ------------------------- -------------- 8.1/12.6 MB 969.7 kB/s eta 0:00:05
#    -------------------------- ------------- 8.4/12.6 MB 979.4 kB/s eta 0:00:05
#    --------------------------- ------------ 8.7/12.6 MB 985.0 kB/s eta 0:00:05
#    ---------------------------- ----------- 8.9/12.6 MB 988.7 kB/s eta 0:00:04
#    ----------------------------- ---------- 9.2/12.6 MB 988.6 kB/s eta 0:00:04
#    ----------------------------- ---------- 9.4/12.6 MB 997.0 kB/s eta 0:00:04
#    ------------------------------ --------- 9.7/12.6 MB 998.3 kB/s eta 0:00:03
#    ------------------------------ --------- 9.7/12.6 MB 998.3 kB/s eta 0:00:03
#    ------------------------------- -------- 10.0/12.6 MB 1.0 MB/s eta 0:00:03
#    ------------------------------- -------- 10.0/12.6 MB 1.0 MB/s eta 0:00:03
#    ------------------------------- -------- 10.0/12.6 MB 1.0 MB/s eta 0:00:03
#    -------------------------------- ------- 10.2/12.6 MB 945.9 kB/s eta 0:00:03
#    --------------------------------- ------ 10.5/12.6 MB 959.4 kB/s eta 0:00:03
#    ---------------------------------- ----- 10.7/12.6 MB 971.2 kB/s eta 0:00:02
#    ---------------------------------- ----- 11.0/12.6 MB 972.9 kB/s eta 0:00:02
#    ---------------------------------- ----- 11.0/12.6 MB 972.9 kB/s eta 0:00:02
#    ----------------------------------- ---- 11.3/12.6 MB 965.3 kB/s eta 0:00:02
#    ----------------------------------- ---- 11.3/12.6 MB 965.3 kB/s eta 0:00:02
#    ----------------------------------- ---- 11.3/12.6 MB 965.3 kB/s eta 0:00:02
#    ----------------------------------- ---- 11.3/12.6 MB 965.3 kB/s eta 0:00:02
#    ----------------------------------- ---- 11.3/12.6 MB 965.3 kB/s eta 0:00:02
#    ----------------------------------- ---- 11.3/12.6 MB 965.3 kB/s eta 0:00:02
#    ----------------------------------- ---- 11.3/12.6 MB 965.3 kB/s eta 0:00:02
#    ------------------------------------ --- 11.5/12.6 MB 859.8 kB/s eta 0:00:02
#    -------------------------------------- - 12.1/12.6 MB 890.3 kB/s eta 0:00:01
#    ---------------------------------------  12.3/12.6 MB 898.4 kB/s eta 0:00:01
#    ---------------------------------------  12.3/12.6 MB 898.4 kB/s eta 0:00:01
#    ---------------------------------------  12.3/12.6 MB 898.4 kB/s eta 0:00:01
#    ---------------------------------------  12.3/12.6 MB 898.4 kB/s eta 0:00:01
#    ---------------------------------------  12.3/12.6 MB 898.4 kB/s eta 0:00:01
#    ---------------------------------------  12.3/12.6 MB 898.4 kB/s eta 0:00:01
#    ---------------------------------------  12.6/12.6 MB 832.7 kB/s eta 0:00:01
#    ---------------------------------------- 12.6/12.6 MB 832.1 kB/s eta 0:00:00
# Using cached pytz-2024.2-py2.py3-none-any.whl (508 kB)
# Using cached tzdata-2024.2-py2.py3-none-any.whl (346 kB)
# Installing collected packages: pytz, tzdata, numpy, pandas
# Successfully installed numpy-2.2.1 pandas-2.2.3 pytz-2024.2 tzdata-2024.2
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The scripts f2py.exe and numpy-config.exe are installed in 'c:\Users\Manoj\mcqgen\env\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
import os
import json
import pandas as pd
import traceback

# %%
pip install langchain
# Out:
# Collecting langchain
#   Using cached langchain-0.3.14-py3-none-any.whl.metadata (7.1 kB)
# Collecting PyYAML>=5.3 (from langchain)
#   Downloading PyYAML-6.0.2-cp312-cp312-win_amd64.whl.metadata (2.1 kB)
# Collecting SQLAlchemy<3,>=1.4 (from langchain)
#   Downloading SQLAlchemy-2.0.37-cp312-cp312-win_amd64.whl.metadata (9.9 kB)
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain)
#   Downloading aiohttp-3.11.11-cp312-cp312-win_amd64.whl.metadata (8.0 kB)
# Collecting langchain-core<0.4.0,>=0.3.29 (from langchain)
#   Downloading langchain_core-0.3.30-py3-none-any.whl.metadata (6.3 kB)
# Collecting langchain-text-splitters<0.4.0,>=0.3.3 (from langchain)
#   Using cached langchain_text_splitters-0.3.5-py3-none-any.whl.metadata (2.3 kB)
# Collecting langsmith<0.3,>=0.1.17 (from langchain)
#   Downloading langsmith-0.2.11-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: numpy<3,>=1.26.2 in c:\users\manoj\mcqgen\env\lib\site-packages (from langchain) (2.2.1)
# Collecting pydantic<3.0.0,>=2.7.4 (from langchain)
#   Downloading pydantic-2.10.5-py3-none-any.whl.metadata (30 kB)
# Collecting requests<3,>=2 (from langchain)
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting tenacity!=8.4.0,<10,>=8.1.0 (from langchain)
#   Downloading tenacity-9.0.0-py3-none-any.whl.metadata (1.2 kB)
# Collecting aiohappyeyeballs>=2.3.0 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Using cached aiohappyeyeballs-2.4.4-py3-none-any.whl.metadata (6.1 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Downloading aiosignal-1.3.2-py2.py3-none-any.whl.metadata (3.8 kB)
# Collecting attrs>=17.3.0 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Using cached attrs-24.3.0-py3-none-any.whl.metadata (11 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Downloading frozenlist-1.5.0-cp312-cp312-win_amd64.whl.metadata (14 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Downloading multidict-6.1.0-cp312-cp312-win_amd64.whl.metadata (5.1 kB)
# Collecting propcache>=0.2.0 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Downloading propcache-0.2.1-cp312-cp312-win_amd64.whl.metadata (9.5 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Downloading yarl-1.18.3-cp312-cp312-win_amd64.whl.metadata (71 kB)
# Collecting jsonpatch<2.0,>=1.33 (from langchain-core<0.4.0,>=0.3.29->langchain)
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\manoj\mcqgen\env\lib\site-packages (from langchain-core<0.4.0,>=0.3.29->langchain) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\manoj\mcqgen\env\lib\site-packages (from langchain-core<0.4.0,>=0.3.29->langchain) (4.12.2)
# Collecting httpx<1,>=0.23.0 (from langsmith<0.3,>=0.1.17->langchain)
#   Downloading httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting orjson<4.0.0,>=3.9.14 (from langsmith<0.3,>=0.1.17->langchain)
#   Using cached orjson-3.10.14-cp312-cp312-win_amd64.whl.metadata (42 kB)
# Collecting requests-toolbelt<2.0.0,>=1.0.0 (from langsmith<0.3,>=0.1.17->langchain)
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<3.0.0,>=2.7.4->langchain)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.27.2 (from pydantic<3.0.0,>=2.7.4->langchain)
#   Downloading pydantic_core-2.27.2-cp312-cp312-win_amd64.whl.metadata (6.7 kB)
# Collecting charset-normalizer<4,>=2 (from requests<3,>=2->langchain)
#   Downloading charset_normalizer-3.4.1-cp312-cp312-win_amd64.whl.metadata (36 kB)
# Collecting idna<4,>=2.5 (from requests<3,>=2->langchain)
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests<3,>=2->langchain)
#   Downloading urllib3-2.3.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests<3,>=2->langchain)
#   Using cached certifi-2024.12.14-py3-none-any.whl.metadata (2.3 kB)
# Collecting greenlet!=0.4.17 (from SQLAlchemy<3,>=1.4->langchain)
#   Downloading greenlet-3.1.1-cp312-cp312-win_amd64.whl.metadata (3.9 kB)
# Collecting anyio (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain)
#   Downloading anyio-4.8.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain)
#   Using cached httpcore-1.0.7-py3-none-any.whl.metadata (21 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain)
#   Using cached h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.29->langchain)
#   Using cached jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Collecting sniffio>=1.1 (from anyio->httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain)
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Using cached langchain-0.3.14-py3-none-any.whl (1.0 MB)
# Downloading aiohttp-3.11.11-cp312-cp312-win_amd64.whl (437 kB)
# Downloading langchain_core-0.3.30-py3-none-any.whl (411 kB)
# Using cached langchain_text_splitters-0.3.5-py3-none-any.whl (31 kB)
# Downloading langsmith-0.2.11-py3-none-any.whl (326 kB)
# Downloading pydantic-2.10.5-py3-none-any.whl (431 kB)
# Downloading pydantic_core-2.27.2-cp312-cp312-win_amd64.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.0 MB ? eta -:--:--
#    ---------- ----------------------------- 0.5/2.0 MB 1.0 MB/s eta 0:00:02
#    --------------- ------------------------ 0.8/2.0 MB 1.2 MB/s eta 0:00:02
#    --------------------- ------------------ 1.0/2.0 MB 1.3 MB/s eta 0:00:01
#    -------------------------- ------------- 1.3/2.0 MB 1.3 MB/s eta 0:00:01
#    ------------------------------- -------- 1.6/2.0 MB 1.3 MB/s eta 0:00:01
#    ------------------------------------ --- 1.8/2.0 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 1.1 MB/s eta 0:00:00
# Downloading PyYAML-6.0.2-cp312-cp312-win_amd64.whl (156 kB)
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Downloading SQLAlchemy-2.0.37-cp312-cp312-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.5/2.1 MB 1.4 MB/s eta 0:00:02
#    -------------- ------------------------- 0.8/2.1 MB 1.3 MB/s eta 0:00:01
#    ------------------- -------------------- 1.0/2.1 MB 1.4 MB/s eta 0:00:01
#    ------------------------ --------------- 1.3/2.1 MB 1.1 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.6/2.1 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 1.3 MB/s eta 0:00:00
# Downloading tenacity-9.0.0-py3-none-any.whl (28 kB)
# Using cached aiohappyeyeballs-2.4.4-py3-none-any.whl (14 kB)
# Downloading aiosignal-1.3.2-py2.py3-none-any.whl (7.6 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached attrs-24.3.0-py3-none-any.whl (63 kB)
# Using cached certifi-2024.12.14-py3-none-any.whl (164 kB)
# Downloading charset_normalizer-3.4.1-cp312-cp312-win_amd64.whl (102 kB)
# Downloading frozenlist-1.5.0-cp312-cp312-win_amd64.whl (51 kB)
# Downloading greenlet-3.1.1-cp312-cp312-win_amd64.whl (299 kB)
# Downloading httpx-0.28.1-py3-none-any.whl (73 kB)
# Using cached httpcore-1.0.7-py3-none-any.whl (78 kB)
# Using cached idna-3.10-py3-none-any.whl (70 kB)
# Using cached jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading multidict-6.1.0-cp312-cp312-win_amd64.whl (28 kB)
# Using cached orjson-3.10.14-cp312-cp312-win_amd64.whl (133 kB)
# Downloading propcache-0.2.1-cp312-cp312-win_amd64.whl (44 kB)
# Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Downloading urllib3-2.3.0-py3-none-any.whl (128 kB)
# Downloading yarl-1.18.3-cp312-cp312-win_amd64.whl (90 kB)
# Using cached jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Downloading anyio-4.8.0-py3-none-any.whl (96 kB)
# Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Installing collected packages: urllib3, tenacity, sniffio, PyYAML, pydantic-core, propcache, orjson, multidict, jsonpointer, idna, h11, greenlet, frozenlist, charset-normalizer, certifi, attrs, annotated-types, aiohappyeyeballs, yarl, SQLAlchemy, requests, pydantic, jsonpatch, httpcore, anyio, aiosignal, requests-toolbelt, httpx, aiohttp, langsmith, langchain-core, langchain-text-splitters, langchain
# Successfully installed PyYAML-6.0.2 SQLAlchemy-2.0.37 aiohappyeyeballs-2.4.4 aiohttp-3.11.11 aiosignal-1.3.2 annotated-types-0.7.0 anyio-4.8.0 attrs-24.3.0 certifi-2024.12.14 charset-normalizer-3.4.1 frozenlist-1.5.0 greenlet-3.1.1 h11-0.14.0 httpcore-1.0.7 httpx-0.28.1 idna-3.10 jsonpatch-1.33 jsonpointer-3.0.0 langchain-0.3.14 langchain-core-0.3.30 langchain-text-splitters-0.3.5 langsmith-0.2.11 multidict-6.1.0 orjson-3.10.14 propcache-0.2.1 pydantic-2.10.5 pydantic-core-2.27.2 requests-2.32.3 requests-toolbelt-1.0.0 sniffio-1.3.1 tenacity-9.0.0 urllib3-2.3.0 yarl-1.18.3
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script normalizer.exe is installed in 'c:\Users\Manoj\mcqgen\env\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script httpx.exe is installed in 'c:\Users\Manoj\mcqgen\env\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script langsmith.exe is installed in 'c:\Users\Manoj\mcqgen\env\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script langchain-server.exe is installed in 'c:\Users\Manoj\mcqgen\env\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
pip install langchain-community
# Out:
# Collecting langchain-community
#   Downloading langchain_community-0.3.14-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\manoj\mcqgen\env\lib\site-packages (from langchain-community) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\manoj\mcqgen\env\lib\site-packages (from langchain-community) (2.0.37)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\manoj\mcqgen\env\lib\site-packages (from langchain-community) (3.11.11)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain-community)
#   Using cached dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting httpx-sse<0.5.0,>=0.4.0 (from langchain-community)
#   Downloading httpx_sse-0.4.0-py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: langchain<0.4.0,>=0.3.14 in c:\users\manoj\mcqgen\env\lib\site-packages (from langchain-community) (0.3.14)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.29 in c:\users\manoj\mcqgen\env\lib\site-packages (from langchain-community) (0.3.30)
# Requirement already satisfied: langsmith<0.3,>=0.1.125 in c:\users\manoj\mcqgen\env\lib\site-packages (from langchain-community) (0.2.11)
# Requirement already satisfied: numpy<3,>=1.26.2 in c:\users\manoj\mcqgen\env\lib\site-packages (from langchain-community) (2.2.1)
# Collecting pydantic-settings<3.0.0,>=2.4.0 (from langchain-community)
#   Downloading pydantic_settings-2.7.1-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: requests<3,>=2 in c:\users\manoj\mcqgen\env\lib\site-packages (from langchain-community) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in c:\users\manoj\mcqgen\env\lib\site-packages (from langchain-community) (9.0.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\manoj\mcqgen\env\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\manoj\mcqgen\env\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\manoj\mcqgen\env\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\manoj\mcqgen\env\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\manoj\mcqgen\env\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\manoj\mcqgen\env\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\manoj\mcqgen\env\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.18.3)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading marshmallow-3.25.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Using cached typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.3 in c:\users\manoj\mcqgen\env\lib\site-packages (from langchain<0.4.0,>=0.3.14->langchain-community) (0.3.5)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\manoj\mcqgen\env\lib\site-packages (from langchain<0.4.0,>=0.3.14->langchain-community) (2.10.5)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\manoj\mcqgen\env\lib\site-packages (from langchain-core<0.4.0,>=0.3.29->langchain-community) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\manoj\mcqgen\env\lib\site-packages (from langchain-core<0.4.0,>=0.3.29->langchain-community) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\manoj\mcqgen\env\lib\site-packages (from langchain-core<0.4.0,>=0.3.29->langchain-community) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\manoj\mcqgen\env\lib\site-packages (from langsmith<0.3,>=0.1.125->langchain-community) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\manoj\mcqgen\env\lib\site-packages (from langsmith<0.3,>=0.1.125->langchain-community) (3.10.14)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\manoj\mcqgen\env\lib\site-packages (from langsmith<0.3,>=0.1.125->langchain-community) (1.0.0)
# Collecting python-dotenv>=0.21.0 (from pydantic-settings<3.0.0,>=2.4.0->langchain-community)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\manoj\mcqgen\env\lib\site-packages (from requests<3,>=2->langchain-community) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\manoj\mcqgen\env\lib\site-packages (from requests<3,>=2->langchain-community) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\manoj\mcqgen\env\lib\site-packages (from requests<3,>=2->langchain-community) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\manoj\mcqgen\env\lib\site-packages (from requests<3,>=2->langchain-community) (2024.12.14)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\manoj\mcqgen\env\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain-community) (3.1.1)
# Requirement already satisfied: anyio in c:\users\manoj\mcqgen\env\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain-community) (4.8.0)
# Requirement already satisfied: httpcore==1.* in c:\users\manoj\mcqgen\env\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain-community) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\manoj\mcqgen\env\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain-community) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\manoj\mcqgen\env\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.29->langchain-community) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\manoj\mcqgen\env\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.14->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\manoj\mcqgen\env\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.14->langchain-community) (2.27.2)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Using cached mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: sniffio>=1.1 in c:\users\manoj\mcqgen\env\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain-community) (1.3.1)
# Downloading langchain_community-0.3.14-py3-none-any.whl (2.5 MB)
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.5 MB 1.9 MB/s eta 0:00:02
#    -------- ------------------------------- 0.5/2.5 MB 1.9 MB/s eta 0:00:02
#    -------- ------------------------------- 0.5/2.5 MB 1.9 MB/s eta 0:00:02
#    -------- ------------------------------- 0.5/2.5 MB 1.9 MB/s eta 0:00:02
#    ------------ --------------------------- 0.8/2.5 MB 532.8 kB/s eta 0:00:04
#    ---------------- ----------------------- 1.0/2.5 MB 729.5 kB/s eta 0:00:02
#    ------------------------- -------------- 1.6/2.5 MB 943.0 kB/s eta 0:00:01
#    ----------------------------- ---------- 1.8/2.5 MB 1.0 MB/s eta 0:00:01
#    --------------------------------- ------ 2.1/2.5 MB 1.1 MB/s eta 0:00:01
#    ---------------------------------------- 2.5/2.5 MB 1.1 MB/s eta 0:00:00
# Using cached dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading httpx_sse-0.4.0-py3-none-any.whl (7.8 kB)
# Downloading pydantic_settings-2.7.1-py3-none-any.whl (29 kB)
# Downloading marshmallow-3.25.1-py3-none-any.whl (49 kB)
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Using cached typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Using cached mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: python-dotenv, mypy-extensions, marshmallow, httpx-sse, typing-inspect, pydantic-settings, dataclasses-json, langchain-community
# Successfully installed dataclasses-json-0.6.7 httpx-sse-0.4.0 langchain-community-0.3.14 marshmallow-3.25.1 mypy-extensions-1.0.0 pydantic-settings-2.7.1 python-dotenv-1.0.1 typing-inspect-0.9.0
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script dotenv.exe is installed in 'c:\Users\Manoj\mcqgen\env\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
from langchain.chat_models import ChatOpenAI

# %%
from dotenv import load_dotenv

load_dotenv()  # take environment variables from .env.
# Out:
# True

# %%
KEY=os.getenv("OPENAI_API_KEY")

# %%
print(KEY)
# Out:
# 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

# %%
llm=ChatOpenAI(openai_api_key=KEY,model_name="gpt-3.5-turbo", temperature=0.5)
